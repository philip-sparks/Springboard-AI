# %% [markdown]
# ## Part 0: Data Collection from Google Big Query

# %% [markdown]
# ### Add authentication credentials to access Big Query API

# %%
# import os
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/psparks/Documents/Springboard/GDELT Testing-31a7081b0cbc.json"

# %% [markdown]
# ### The BigQuery Python client library provides a magic command that allows you to run queries with minimal code. To load the magic commands from the client library, paste the following code into the first cell of the notebook.

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# ### The BigQuery client library provides a cell magic,  _%%bigquery_, which runs a SQL query of all French BigQuery events since Feb. 1 2016 and returns the results as a Pandas DataFrame.

# %%
# %%bigquery france_subset
# SELECT *
# FROM `gdelt-bq.full.events`
# WHERE ActionGeo_CountryCode = 'FR' AND MonthYear >= 201601

# %%
# france_subset.shape

# %% [markdown]
# ### After downloading data, save it for future use

# %%
# france_subset.to_csv('france_subset_1619_2.csv.bz2', header = True, compression='bz2')

# %% [markdown]
# ### Now read it back for future data wrangling

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
import warnings; warnings.simplefilter('ignore')

# %%
# %time # ~ 6mins
france_subset = pd.read_csv('france_subset_1619_2.csv.bz2', compression='bz2')
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 14.1 µs

# %%
france_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 59 columns):
# Unnamed: 0               int64
# GLOBALEVENTID            int64
# SQLDATE                  int64
# MonthYear                int64
# Year                     int64
# FractionDate             float64
# Actor1Code               object
# Actor1Name               object
# Actor1CountryCode        object
# Actor1KnownGroupCode     object
# Actor1EthnicCode         object
# Actor1Religion1Code      object
# Actor1Religion2Code      object
# Actor1Type1Code          object
# Actor1Type2Code          object
# Actor1Type3Code          object
# Actor2Code               object
# Actor2Name               object
# Actor2CountryCode        object
# Actor2KnownGroupCode     object
# Actor2EthnicCode         object
# Actor2Religion1Code      object
# Actor2Religion2Code      object
# Actor2Type1Code          object
# Actor2Type2Code          object
# Actor2Type3Code          object
# IsRootEvent              int64
# EventCode                int64
# EventBaseCode            int64
# EventRootCode            int64
# QuadClass                int64
# GoldsteinScale           float64
# NumMentions              int64
# NumSources               int64
# NumArticles              int64
# AvgTone                  float64
# Actor1Geo_Type           int64
# Actor1Geo_FullName       object
# Actor1Geo_CountryCode    object
# Actor1Geo_ADM1Code       object
# Actor1Geo_Lat            float64
# Actor1Geo_Long           float64
# Actor1Geo_FeatureID      object
# Actor2Geo_Type           int64
# Actor2Geo_FullName       object
# Actor2Geo_CountryCode    object
# Actor2Geo_ADM1Code       object
# Actor2Geo_Lat            float64
# Actor2Geo_Long           float64
# Actor2Geo_FeatureID      object
# ActionGeo_Type           int64
# ActionGeo_FullName       object
# ActionGeo_CountryCode    object
# ActionGeo_ADM1Code       object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# ActionGeo_FeatureID      object
# DATEADDED                int64
# SOURCEURL                object
# dtypes: float64(9), int64(17), object(33)
# memory usage: 1.4+ GB

# %% [markdown]
# ## Part 1: Data Cleaning

# %% [markdown]
# ### Let review what data we have.

# %%
france_subset.head()
# Out:
#    Unnamed: 0  GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate  \
# 0           0      523961397  20160324     201603  2016   2016.230100
# 1           1      521622559  20160316     201603  2016   2016.208200
# 2           2      516418595  20160229     201602  2016   2016.161621
# 3           3      522928257  20160321     201603  2016   2016.221900
# 4           4      538837301  20160510     201605  2016   2016.356200
#
#   Actor1Code Actor1Name Actor1CountryCode Actor1KnownGroupCode  \
# 0        NaN        NaN               NaN                  NaN
# 1        NaN        NaN               NaN                  NaN
# 2        NaN        NaN               NaN                  NaN
# 3        NaN        NaN               NaN                  NaN
# 4        NaN        NaN               NaN                  NaN
#
#                          ...                         Actor2Geo_FeatureID  \
# 0                        ...                                          FR
# 1                        ...                                          FR
# 2                        ...                                          FR
# 3                        ...                                          FR
# 4                        ...                                    -1409795
#
#   ActionGeo_Type                        ActionGeo_FullName  \
# 0              1                                    France
# 1              1                                    France
# 2              1                                    France
# 3              1                                    France
# 4              4  French Riviera, France (general), France
#
#   ActionGeo_CountryCode ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long  \
# 0                    FR                 FR       46.0000        2.00000
# 1                    FR                 FR       46.0000        2.00000
# 2                    FR                 FR       46.0000        2.00000
# 3                    FR                 FR       46.0000        2.00000
# 4                    FR               FR00       43.5599        7.13672
#
#   ActionGeo_FeatureID DATEADDED  \
# 0                  FR  20160324
# 1                  FR  20160316
# 2                  FR  20160229
# 3                  FR  20160321
# 4            -1409795  20160510
#
#                                            SOURCEURL
# 0  http://www.goldcoastbulletin.com.au/news/natio...
# 1  http://www.newsmax.com/TheWire/italy-unsold-fo...
# 2  http://www.irishtimes.com/life-and-style/peopl...
# 3  http://www.ibtimes.co.uk/malaysia-palm-oil-cou...
# 4  http://movies.ndtv.com/bollywood/en-route-cann...
#
# [5 rows x 59 columns]

# %% [markdown]
# ### We are going to subset the data based on the most relevant columns, according to source: https://jameshoward.us/wp-content/uploads/2018/03/Parrish-Crystal-Cube.pdf

# %%
france_events = france_subset[['SQLDATE', 'Actor1Name', 'Actor2Name', 'SOURCEURL', 'MonthYear', 'EventRootCode', 'GoldsteinScale', 'NumMentions', 'AvgTone', 'ActionGeo_CountryCode', 'ActionGeo_Lat', 'ActionGeo_Long']]

# %%
france_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 12 columns):
# SQLDATE                  int64
# Actor1Name               object
# Actor2Name               object
# SOURCEURL                object
# MonthYear                int64
# EventRootCode            int64
# GoldsteinScale           float64
# NumMentions              int64
# AvgTone                  float64
# ActionGeo_CountryCode    object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 284.2+ MB

# %% [markdown]
# ### Convert SQLDATE to datetime format

# %%
france_events.SQLDATE = pd.to_datetime(france_subset.SQLDATE, format = '%Y%m%d')

# %%
france_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 12 columns):
# SQLDATE                  datetime64[ns]
# Actor1Name               object
# Actor2Name               object
# SOURCEURL                object
# MonthYear                int64
# EventRootCode            int64
# GoldsteinScale           float64
# NumMentions              int64
# AvgTone                  float64
# ActionGeo_CountryCode    object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 284.2+ MB

# %%
#france_events.sort_values(by=['SOURCEURL'], ascending=True).iloc[:5]
# Out:
#            SQLDATE Actor1Name           Actor2Name  \
# 334888  2016-02-23     MINIST                PARIS
# 1571981 2016-02-23    UKRAINE  GOVERNMENT OFFICIAL
# 1573287 2016-02-23        NaN                PARIS
# 491420  2017-03-09   DIPLOMAT               FRANCE
# 2045042 2017-03-09  UKRAINIAN               FRANCE
#
#                                        SOURCEURL  MonthYear  EventRootCode  \
# 334888   5 Kanal TV, Kiev/BBC Monitoring/(c) BBC     201602              4
# 1571981  5 Kanal TV, Kiev/BBC Monitoring/(c) BBC     201602              4
# 1573287  5 Kanal TV, Kiev/BBC Monitoring/(c) BBC     201602              4
# 491420   5 Kanal TV, Kiev/BBC Monitoring/(c) BBC     201703              4
# 2045042  5 Kanal TV, Kiev/BBC Monitoring/(c) BBC     201703              4
#
#          GoldsteinScale  NumMentions   AvgTone ActionGeo_CountryCode  \
# 334888              1.0            1 -0.302115                    FR
# 1571981             7.0            1  3.021148                    FR
# 1573287             1.0            8  3.021148                    FR
# 491420              1.0            6  2.272727                    FR
# 2045042             1.0            1  2.272727                    FR
#
#          ActionGeo_Lat  ActionGeo_Long
# 334888         49.0000         0.00000
# 1571981        49.0000         0.00000
# 1573287        48.8667         2.33333
# 491420         49.0000         0.00000
# 2045042        48.8667         2.33333

# %%
france_events.sample(10)
# Out:
#            SQLDATE      Actor1Name Actor2Name  \
# 2797311 2016-05-21         STUDENT     FRANCE
# 623583  2016-05-21  SECURITY FORCE  PRESIDENT
# 2747484 2016-05-03        EUROPEAN        NaN
# 1371178 2017-03-29          EUROPE     FRANCE
# 377671  2018-05-28      PROSECUTOR     FRANCE
# 1724893 2017-02-16            ROME        NaN
# 236550  2018-11-08         RUSSIAN      SYRIA
# 1628926 2019-04-11          AFRICA      TUNIS
# 194538  2018-03-05          GOOGLE     FRANCE
# 548440  2019-05-22          FRENCH   CIVILIAN
#
#                                                  SOURCEURL  MonthYear  \
# 2797311  http://www.peacearchnews.com/national/38030041...     201605
# 623583   http://www.jewishaz.com/us_worldnews/world/fre...     201605
# 2747484  http://consequenceofsound.net/2016/05/win-vip-...     201605
# 1371178  http://www.ctvnews.ca/canada/vimy-ridge-canadi...     201703
# 377671   https://www.thestar.com/news/world/2018/05/28/...     201805
# 1724893  http://blogs.bl.uk/digitisedmanuscripts/2017/0...     201702
# 236550   https://www.al-monitor.com/pulse/originals/201...     201811
# 1628926  https://www.prnewswire.com/news-releases/afric...     201904
# 194538   https://www.tax-news.com/news/Frances_Le_Maire...     201803
# 548440   https://www.theguardian.com/world/2019/may/22/...     201905
#
#          EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 2797311              1             0.0           96 -2.143074
# 623583              14            -6.5            3 -7.633588
# 2747484              2             3.4           10  2.602230
# 1371178             17            -5.0            4  2.247191
# 377671               1             0.0           11  0.004519
# 1724893              1             0.0            3 -0.496524
# 236550               4             1.9            1 -0.931414
# 1628926              4             1.0           10  4.695652
# 194538              19           -10.0           10 -3.311258
# 548440               5             3.8            4 -5.605137
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long
# 2797311                    FR        48.8667         2.33333
# 623583                     FR        48.8667         2.33333
# 2747484                    FR        46.0000         2.00000
# 1371178                    FR        50.3724         2.81034
# 377671                     FR        48.4353         4.38201
# 1724893                    FR        48.8667         2.33333
# 236550                     FR        48.8667         2.33333
# 1628926                    FR        48.8667         2.33333
# 194538                     FR        46.0000         2.00000
# 548440                     FR        48.8667         2.33333

# %% [markdown]
# ### Notice how we can't see the full URLs yet? Let's try to change that.

# %%
pd.set_option('display.max_colwidth', -1)

# %%
france_events.sample(5, random_state=1)
# Out:
#            SQLDATE Actor1Name      Actor2Name  \
# 2130769 2018-09-01  PRESIDENT  PARIS
# 1242414 2016-02-05  PARIS      TERRORIST
# 2550644 2018-05-29  CANADA     COMMUNITY
# 2984274 2019-03-05  FRENCH     NaN
# 1304530 2018-05-06  BRITAIN    UNITED KINGDOM
#
#                                                                                                                                                SOURCEURL  \
# 2130769  https://www.goskagit.com/news/world/how-macron-won-trump-s-friendship-failed-to-influence-him/article_40161889-95f8-58f9-996e-f156d774a9d8.html
# 1242414  http://www.arabnews.com/news/875471
# 2550644  http://www.yorktonnews.com/france-s-macron-to-meet-trudeau-visit-montreal-ahead-of-g7-summit-in-quebec-1.23317715
# 2984274  https://www.msn.com/en-sg/lifestyle/style/teeny-tiny-handbag-becomes-a-fashion-sensation/ar-BBUnjMk
# 1304530  https://www.bignewsnetwork.com/news/257198553/trump-stirs-another-controversy-over-gun-laws-uk-fumes
#
#          MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 2130769  201809     4              1.9             16           2.119462
# 1242414  201602     20            -10.0            20          -3.047394
# 2550644  201805     1              0.0             2            0.847458
# 2984274  201903     11            -2.0             318          1.216732
# 1304530  201805     3              4.0             1           -5.350118
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long
# 2130769  FR                    48.8667        2.33333
# 1242414  FR                    48.8667        2.33333
# 2550644  FR                    48.8667        2.33333
# 2984274  FR                    48.8667        2.33333
# 1304530  FR                    48.8667        2.33333

# %%
france_events.sample(5, random_state=2)
# Out:
#            SQLDATE Actor1Name Actor2Name  \
# 1994159 2017-03-29  PARIS      PREMIER
# 2838338 2018-02-16  BUSINESS   NaN
# 2577313 2017-06-29  NAVAL      NaN
# 272698  2017-11-29  PARIS      NEW YORK
# 1743688 2019-06-10  JEWISH     FRENCH
#
#                                                                                            SOURCEURL  \
# 1994159  https://www.360nobs.com/2017/03/zlatan-ibrahimovic-hints/
# 2838338  http://www.prweb.com/releases/2018/02/prweb15214603.htm
# 2577313  http://carnegieindia.org/publications/?fa=71395
# 272698   http://www.aljazeera.com/indepth/opinion/slavery-walls-fortress-europe-171128094218944.html
# 1743688  https://harpers.org/blog/2019/06/my-french-side/
#
#          MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 1994159  201703     4              2.8             6            1.694915
# 2838338  201802     1              0.0             6            5.280528
# 2577313  201706     2              3.0             5            3.324808
# 272698   201711     14            -6.5             6           -6.577480
# 1743688  201906     5              3.5             2           -0.941423
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long
# 1994159  FR                    48.8667        2.33333
# 2838338  FR                    47.1672        0.24564
# 2577313  FR                    48.8667        2.33333
# 272698   FR                    48.8667        2.33333
# 1743688  FR                    46.7333        2.70000

# %% [markdown]
# #### After grabbing the full URLs, we're able to see that the subjects in the stories match the actors listed in Actor1Name and Actor2Name.

# %% [markdown]
# ### Those URLs could be cleaned up a bit more in order to group the news by domain name later.

# %%
domains = france_events['SOURCEURL'].str.extract('(?<=http://)(.*?)(?=/)|(?<=https://)(.*?)(?=/)')
domains = domains[0].fillna(domains[1]).fillna(france_events['SOURCEURL'])

# %%
domains[:20]
# Out:
# 0     www.goldcoastbulletin.com.au
# 1     www.newsmax.com
# 2     www.irishtimes.com
# 3     www.ibtimes.co.uk
# 4     movies.ndtv.com
# 5     lompocrecord.com
# 6     www.bbc.co.uk
# 7     www.brisbanetimes.com.au
# 8     www.bloomberg.com
# 9     www.paxtonrecord.net
# 10    www.bloomberg.com
# 11    whoswholegal.com
# 12    www.monitor.co.ug
# 13    onmilwaukee.com
# 14    www.sharenet.co.za
# 15    www.thesudburystar.com
# 16    listverse.com
# 17    mobile.wnd.com
# 18    ecommerce-journal.com
# 19    www.enca.com
# Name: 0, dtype: object

# %%
france_events['DOMAINNAME'] = domains

# %%
france_events.head()
# Out:
#      SQLDATE Actor1Name Actor2Name  \
# 0 2016-03-24  NaN        POLICE
# 1 2016-03-16  NaN        LAWMAKER
# 2 2016-02-29  NaN        IRELAND
# 3 2016-03-21  NaN        FARMER
# 4 2016-05-10  NaN        FRANCE
#
#                                                                                                                                                                                                                       SOURCEURL  \
# 0  http://www.goldcoastbulletin.com.au/news/national/qantas-pilot-believed-to-have-deliberately-crashed-plane-into-sea-off-byron-bay/news-story/2f1b1154e10c139a36312c088424f381?nk=ad15cd490373050ab7a2275d46ead101-1458786743
# 1  http://www.newsmax.com/TheWire/italy-unsold-food-law/2016/03/16/id/719333/
# 2  http://www.irishtimes.com/life-and-style/people/life-and-death-the-rotunda-and-the-rising-1.2549489
# 3  http://www.ibtimes.co.uk/malaysia-palm-oil-council-slams-frances-tax-palm-oil-vows-retaliation-1550662
# 4  http://movies.ndtv.com/bollywood/en-route-cannes-mallika-sherawat-tweets-pic-of-the-eiffel-tower-1404752
#
#    MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 0  201603     1              0.0             84          -2.747776
# 1  201603     1              0.0             2           -0.643087
# 2  201602     4              1.9             8            0.675454
# 3  201603     12            -4.0             10          -5.533493
# 4  201605     4              1.9             2            0.000000
#
#   ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long  \
# 0  FR                    46.0000        2.00000
# 1  FR                    46.0000        2.00000
# 2  FR                    46.0000        2.00000
# 3  FR                    46.0000        2.00000
# 4  FR                    43.5599        7.13672
#
#                      DOMAINNAME
# 0  www.goldcoastbulletin.com.au
# 1  www.newsmax.com
# 2  www.irishtimes.com
# 3  www.ibtimes.co.uk
# 4  movies.ndtv.com

# %%
france_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 13 columns):
# SQLDATE                  datetime64[ns]
# Actor1Name               object
# Actor2Name               object
# SOURCEURL                object
# MonthYear                int64
# EventRootCode            int64
# GoldsteinScale           float64
# NumMentions              int64
# AvgTone                  float64
# ActionGeo_CountryCode    object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# DOMAINNAME               object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 307.8+ MB

# %% [markdown]
# ### Of our remaining columns, which ones have missing values?

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
        return mz_table

# %%
missing_zero_values_table(france_events)
# Out:
# Your selected dataframe has 13 columns and 3103885 Rows.
# There are 3 columns that have missing values.
#                 Zero Values  Missing Values  % of Total Values  \
# Actor2Name      0            645666          20.8
# Actor1Name      0            212579          6.8
# GoldsteinScale  293127       52              0.0
#
#                 Total Zero Missing Values  % Total Zero Missing Values  \
# Actor2Name      645666                     20.8
# Actor1Name      212579                     6.8
# GoldsteinScale  293179                     9.4
#
#                Data Type
# Actor2Name      object
# Actor1Name      object
# GoldsteinScale  float64

# %% [markdown]
#  ### Adding the actor names may take a lot of web scraping and NLP processing that may be of dubious value at the moment, but having missing `GoldsteinScale` values would definitely skew our predictions later.

# %%
france_events[france_events['GoldsteinScale'].isnull()]
# Out:
#            SQLDATE        Actor1Name      Actor2Name  \
# 10853   2016-03-17  DISSIDENT         RUSSIA
# 61541   2019-03-19  FRANCE            RUSSIA
# 69189   2016-03-22  NaN               FRANCE
# 76295   2016-03-16  FRANCE            RUSSIA
# 192692  2016-03-21  LAWYER            FRANCE
# 264112  2016-03-09  FRANCE            THE NETHERLAND
# 266258  2016-03-21  NaN               FRANCE
# 271626  2016-03-20  NaN               FRANCE
# 327096  2016-12-10  FRANCE            RUSSIA
# 335268  2016-03-16  FRANCE            RUSSIA
# 380463  2016-05-31  POLAND            UNITED STATES
# 495577  2016-03-16  FRENCH            RUSSIA
# 500201  2016-03-16  PARIS             RUSSIA
# 503770  2016-03-22  LAWYER            FRANCE
# 642109  2016-03-22  LAWYER            FRANCE
# 642124  2016-03-08  FRANCE            THE NETHERLAND
# 690226  2016-05-31  POLAND            UNITED STATES
# 764569  2017-06-09  POLISH            THE US
# 835533  2016-03-21  NaN               FRANCE
# 931562  2016-03-16  ASSOCIATED PRESS  RUSSIA
# 932238  2016-03-09  FRANCE            THE NETHERLAND
# 932929  2016-03-21  LAWYER            FRANCE
# 500201   ktar.com
# 503770   www.ndtv.com
# 642109   www.ndtv.com
# 642124   news.yahoo.com
# 690226   www.texomashomepage.com
# 764569   www.independent.co.uk
# 835533   www.iusbpreface.com
# 931562   www.washingtonpost.com
# 932238   www.manilatimes.net
# 932929   www.ndtv.com
# 951053   www.worldbulletin.net
# 1230985  www.naharnet.com
# 1251638  www.sandiegouniontribune.com
# 1377317  www.digitaljournal.com
# 1432506  news.yahoo.com
# 1469944  www.bbc.com
# 1567699  www.telegraph.co.uk
# 1567702  au.finance.yahoo.com
# 1567715  www.telegraph.co.uk
# 1582913  hosted2.ap.org
# 1631696  en.tengrinews.kz
# 1749977  www.ajc.com
# 1802364  www.washingtonpost.com
# 1870511  borneobulletin.com.bn
# 1879694  au.finance.yahoo.com
# 1883348  abcnews.go.com
# 1918076  www.theguardian.com
# 1995389  www.thenews.com.pk
# 2146761  hosted2.ap.org
# 2189819  www.dw.com
# 2311906  www.fourstateshomepage.com
# 2454489  www.naharnet.com
# 2499681  www.dw.com
# 2754966  hosted2.ap.org
# 2757451  en.africatime.com
# 2810300  www.worldbulletin.net
# 2810386  home.bt.com
# 2930385  www.yahoo.com
# 2938031  www.independent.co.uk
# 3053861  www.heraldlive.co.za

# %% [markdown]
# ### After reviewing the stories from the URL, they mostly seem to deal with a fairly negative and escalatory action taken by the French government. The Goldstein scale typically gives these stories a `-5` rating based on their WEIS charts, so that's what I will add.

# %%
france_events['GoldsteinScale'] = france_events['GoldsteinScale'].fillna(value= -5)

# %% [markdown]
# #### Example row where the `GoldsteinScale` was previously empty.

# %%
france_events.iloc[[1749977]]
# Out:
#            SQLDATE Actor1Name Actor2Name  \
# 1749977 2016-03-16  FRENCH     RUSSIA
#
#                                                                                            SOURCEURL  \
# 1749977  http://www.ajc.com/ap/ap/top-news/kazakh-bankers-wife-urges-france-not-to-send-him-t/nqmXb/
#
#          MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 1749977  201603     12            -5.0             48          -11.01576
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long   DOMAINNAME
# 1749977  FR                    48.8667        2.33333         www.ajc.com

# %%
missing_zero_values_table(france_events)
# Out:
# Your selected dataframe has 13 columns and 3103885 Rows.
# There are 2 columns that have missing values.
#             Zero Values  Missing Values  % of Total Values  \
# Actor2Name  0            645666          20.8
# Actor1Name  0            212579          6.8
#
#             Total Zero Missing Values  % Total Zero Missing Values Data Type
# Actor2Name  645666                     20.8                         object
# Actor1Name  212579                     6.8                          object

# %% [markdown]
# ### Part one summary:
#  - Formatted the `SQLDATE` to a Pandas datetime object.
#  - Extracted the URL from the `SOURCEURL` and gave placed it into the `DOMAINNAME` column
#  - Filled in null data for empty `GoldsteinScale` values.

# %%
del france_subset

# %%
france_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 13 columns):
# SQLDATE                  datetime64[ns]
# Actor1Name               object
# Actor2Name               object
# SOURCEURL                object
# MonthYear                int64
# EventRootCode            int64
# GoldsteinScale           float64
# NumMentions              int64
# AvgTone                  float64
# ActionGeo_CountryCode    object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# DOMAINNAME               object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 307.8+ MB

# %% [markdown]
# # New Part: Data Wrangling for ML/Logistic Regression Models

# %% [markdown]
# ## TODO:
# - Group by truncated lat/long values to the first decimal place (Completed 7/31)
# - Add a column if there was an event the next day or not  (Completed 7/31)
# - Train/test split by date (Completed 8/1)
# - Build a logistic model (Completed 8/1)
# - Fit (Completed 8/1)
# - Create a classification report (Completed 8/1)
# - Filter by SourceURL and test again
# - Iterate over each news source to see if different news sources are more predictive than others

# %%
france_events.head()
# Out:
#            SQLDATE   Actor1Name Actor2Name  \
# 76287   2016-02-01  IRAN         FRANCE
# 1504333 2016-02-01  PALESTINIAN  ISRAELI
# 1502271 2016-02-01  NaN          FRANCE
# 2991617 2016-02-01  BRITISH      COLONEL
# 1500747 2016-02-01  PARIS        EUROPEAN
#
#                                                                                                                                                                                                                 SOURCEURL  \
# 76287    http://www.presstv.com/Detail/2016/02/01/448257/Iran-mining-foreign-investment-Karbasian
# 1504333  http://www.menafn.com/1094568238/Netanyahu-criticises-French-threat-to-recognise-Palestinian-state
# 1502271  http://iusbpreface.com/2016/02/01/france-to-build-six-n-reactors-in-india-105014/
# 2991617  http://www.couriermail.com.au/news/world/uk-set-to-deploy-troops-to-libya-to-fight-escalating-islamic-state-terrorism/news-story/8367dd46ab9577db5af2207242db2422?nk=179eeb4d40fb08d89f91b0dda6714c63-1454365043
# 1500747  http://www.winnfm.com/news/regional/15594-on-historic-foray-castro-visits-france-as-cuba-opens-up
#
#          MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 76287    201602     6              6.4             2            1.893939
# 1504333  201602     1              0.0             2           -5.244755
# 1502271  201602     5              8.0             1           -1.401869
# 2991617  201602     13            -4.4             34          -5.389052
# 1500747  201602     4              1.9             8            0.000000
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long  \
# 76287    FR                    48.9           2.33333
# 1504333  FR                    46.0           2.00000
# 1502271  FR                    48.9           2.33333
# 2991617  FR                    46.0           2.00000
# 1500747  FR                    48.9           2.33333
#
#                      DOMAINNAME   LocationRegion  Event
# 76287    www.presstv.com         (48.9, 2.33333)  0
# 1504333  www.menafn.com          (46.0, 2.0)      0
# 1502271  iusbpreface.com         (48.9, 2.33333)  0
# 2991617  www.couriermail.com.au  (46.0, 2.0)      0
# 1500747  www.winnfm.com          (48.9, 2.33333)  0

# %%
decimals = 2    
df['column'] = df['column'].apply(lambda x: round(x, decimals))

# %% [markdown]
# ### Group by truncated lat/long values

# %%
decimals = 1
france_events['ActionGeo_Lat'] = france_events['ActionGeo_Lat'].apply(lambda x: round(x, decimals))

# %%
france_events['ActionGeo_Long'] = france_events['ActionGeo_Long'].apply(lambda x: round(x, decimals))

# %%
france_events['LocationRegion'] = list(zip(france_events.ActionGeo_Lat, france_events.ActionGeo_Long))

# %% [markdown]
# #### Now we will know how many regions the events are clustered in.

# %%
france_events.LocationRegion.nunique()
# Out:
# 8710

# %% [markdown]
# ### Find min and max dates

# %%
print (france_events.SQLDATE.min())
print (france_events.SQLDATE.max())
# Out:
# 2016-02-01 00:00:00
# 2019-06-21 00:00:00

# %% [markdown]
# ### Append ones to dates with an event within this date range.

# %%
# Source: https://www.wikiwand.com/en/List_of_terrorist_incidents_in_France#/21st_century
event_list = ['2016-06-12', '2016-07-13', '2016-07-25', '2017-02-02', '2017-03-15', '2017-03-17', '2017-04-19',
             '2017-06-05', '2017-06-18', '2017-08-08', '2017-09-14', '2017-09-30', '2018-03-22', '2018-05-11',
             '2018-12-10', '2019-03-04', '2019-05-23']

# %%
france_events['Event'] = 0

# %% [markdown]
# ### Check if date is one of the dates in the event list

# %%
france_events['Event'] = france_events['SQLDATE'].isin(event_list)

# %% [markdown]
# ### If so, label it a "1"

# %%
france_events['Event'] = france_events['Event'].apply(lambda x: 1 if x else 0)

# %% [markdown]
# ### Check if changes took place

# %%
france_events.Event.nunique()
# Out:
# 2

# %%
start_date = '2018-12-10'
end_date = '2018-12-11'
mask = (france_events['SQLDATE'] > start_date) & (france_events['SQLDATE'] <= end_date)

# %%
df = france_events.loc[mask]
df
# Out:
#            SQLDATE           Actor1Name           Actor2Name  \
# 97835   2018-12-11  TOKYO                JAPAN
# 98391   2018-12-11  PARIS                POLAND
# 98405   2018-12-11  GOVERNANCE           JAPAN
# 98406   2018-12-11  GOVERNANCE           JAPANESE
# 223627  2018-12-11  BRUSSELS             PROTESTER
# 261905  2018-12-11  AFGHANISTAN          NaN
# 261906  2018-12-11  GHANA                NaN
# 261907  2018-12-11  ITALIAN              NaN
# 261908  2018-12-11  FRENCH               NaN
# 261909  2018-12-11  INTERIOR MINIST      NaN
# 261910  2018-12-11  GOVERNMENT           NaN
# 261911  2018-12-11  FRANCE               NaN
# 261912  2018-12-11  SOCIAL WORKER        NaN
# 261913  2018-12-11  EMPLOYEE             NaN
# 261914  2018-12-11  MARSEILLE            NaN
# 261915  2018-12-11  FRANCE               NaN
# 261916  2018-12-11  FRANCE               NaN
# 261917  2018-12-11  FRANCE               NaN
# 261918  2018-12-11  FRENCH               NaN
# 261919  2018-12-11  PRODUCER             NaN
# 261920  2018-12-11  PROTESTER            NaN
# 261921  2018-12-11  FRANCE               NaN
# 261922  2018-12-11  GOVERNMENT           NaN
# 261923  2018-12-11  FRANCE               NaN
# 261924  2018-12-11  EUROPEAN PARLIAMENT  NaN
# 261925  2018-12-11  FRANCE               NaN
# 262002  2018-12-11  EUROPE               NaN
# 262003  2018-12-11  CONGO                NaN
# 262017  2018-12-11  FRANCE               NaN
# 262018  2018-12-11  PROTESTER            NaN
# ...            ...        ...            ...
# 3056963 2018-12-11  CRIMINAL             INTERIOR MINIST
# 3056964 2018-12-11  FRENCH               PRESIDENTIAL PALACE
# 3056965 2018-12-11  FRANCE               FRANCE
# 3056966 2018-12-11  ASSAILANT            FRANCE
# 3056978 2018-12-11  NaN                  FRANCE
# 3056981 2018-12-11  AL QAEDA             FRANCE
# 3057085  http://www.radio.gov.pk/11-12-2018/fm-invites-malaysian-investors-to-harness-opportunities-in-pakistan
# 3057097  http://jamestown.org/program/russia-fruitlessly-prepares-for-new-sanctions/
# 3057098  https://euobserver.com/foreign/143664
# 3057102  https://www.alternet.org/news-amp-politics/trumps-delusional-alternate-social-media-universe-reveals-his-mounting-concerns
# 3057105  https://www.alaraby.co.uk/english/news/2018/12/11/turkey-in-talks-over-un-investigation-into-khashoggi-murder
# 3057119  https://www.businessinsider.com/r-no-deal-brexit-more-likely-amid-confused-situation-in-london-france-says-2018-12
# 3057126  https://signalscv.com/2018/12/cher-gilmore-good-news-bad-news-on-climate/
# 3057132  http://time.com/person-of-the-year-2018-donald-trump-runner-up/
# 3057133  https://iranian.com/2018/12/11/trump-news-agenda/
# 3057139  https://www.theintelligencer.com/news/politics/article/Trump-political-aides-shifting-over-to-13449440.php
# 3057140  https://www.modernghana.com/news/903262/eye-on-france-what-can-the-president-say-to-ease-anger.html
# 3057151  https://www.modernghana.com/news/903281/global-investors-urge-end-of-coal.html
# 3057153  https://world.wng.org/content/school_sacks_christian_teacher_over_pronoun_use
# 3057157  https://www.sott.net/article/402581-Trans-Tyranny-West-Virginian-HS-teacher-fired-for-not-using-students-preferred-pronoun
# 3057158  https://dailycaller.com/2018/12/11/aleksandr-solzhenitsyn-against-fascism/
#
#          MonthYear  EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 97835    201812     11            -2.0             1           -3.429603
# 98391    201812     3              4.0             10           2.631579
# 98405    201812     17            -5.0             2           -4.704097
# 98406    201812     17            -5.0             6           -4.704097
# 223627   201812     14            -6.5             54          -1.846530
# 261905   201812     4              1.9             1           -1.251476
# 261906   201812     7              7.4             2            2.272727
# 261907   201812     4              2.8             10           1.945525
# 261908   201812     1             -0.4             1           -3.341289
# 261909   201812     1              0.0             64          -6.262439
# 261910   201812     17            -5.0             2           -6.518905
# 261911   201812     18            -9.0             1           -3.703704
# 261912   201812     1              0.0             15          -3.504292
# 261913   201812     7              7.0             10           4.408353
# 261914   201812     1             -0.4             5            0.350263
# 261915   201812     2              3.0             5           -3.835227
# 261916   201812     13            -5.8             10          -6.381164
# 261917   201812     3              4.0             5           -5.732484
# 261918   201812     2              3.0             6           -5.732484
# 261919   201812     4              1.9             2            1.365410
# 261920   201812     3              7.0             20          -7.289294
# 261921   201812     5              3.4             8           -5.485714
# 261922   201812     11            -2.0             10          -3.111495
# 261923   201812     1              0.0             12          -6.316562
# 261924   201812     19            -10.0            85          -8.719690
# 261925   201812     18            -9.0             10          -4.485981
# 262002   201812     5              3.4             4            4.478097
# 262003   201812     14            -7.5             1           -0.715990
# 262017   201812     1              0.0             103         -2.011289
# 262018   201812     18            -9.0             5           -7.368421
# ...         ...     ..             ...            ..                 ...
# 3056963  201812     1              0.0             6           -7.130413
# 3056964  201812     9             -2.0             30          -5.957424
# 3056965  201812     19            -10.0            1           -4.360465
# 3056966  201812     4              2.8             8           -7.473310
# 3056978  201812     8              7.0             8           -8.163265
# 3056981  201812     19            -10.0            2           -7.914152
# 3057019  201812     5              3.4             6           -7.914152
# 3057024  201812     19            -10.0            3           -6.419401
# 3057036  201812     5              3.4             8            0.750000
# 3057049  201812     9             -2.0             1            0.299581
# 3057050  201812     14            -6.5             90          -4.659498
# 3057061  201812     4              1.9             2           -7.843137
# 3057065  201812     8              5.0             4           -3.804348
# 3057070  201812     12            -4.0             2           -5.803571
# 3057078  201812     4              7.0             6            1.990050
# 3057085  201812     2              3.0             7            6.808511
# 3057097  201812     5              8.0             4           -7.981221
# 3057098  201812     5              3.4             2           -5.677419
# 3057102  201812     2              3.0             1           -3.899480
# 3057105  201812     2              3.0             4           -5.714286
# 3057119  201812     1             -0.4             2           -4.615385
# 3057126  201812     5              8.0             7           -0.777202
# 3057132  201812     2              3.0             2           -2.288166
# 3057133  201812     19            -10.0            1           -3.881030
# 3057139  201812     5              3.5             1           -0.775194
# 3057140  201812     1              0.0             2           -3.958333
# 3057151  201812     3              4.0             3           -0.974930
# 3057153  201812     1              0.4             1           -3.713528
# 3057157  201812     3              4.0             4           -0.170068
# 3057158  201812     11            -2.0             12          -6.082037
#
#         ActionGeo_CountryCode  ActionGeo_Lat  ActionGeo_Long  \
# 97835    FR                    46.0           2.000000
# 98391    FR                    48.9           2.333330
# 98405    FR                    48.9           2.333330
# 98406    FR                    48.9           2.333330
# 223627   FR                    46.0           2.000000
# 261905   FR                    48.9           2.333330
# 261906   FR                    48.9           2.333330
# 261907   FR                    49.1           0.226625
# 261908   FR                    46.0           2.000000
# 261909   FR                    48.9           2.333330
# 261910   FR                    48.9           2.553240
# 261911   FR                    48.9           2.333330
# 261912   FR                    43.5           5.448790
# 261913   FR                    50.8           1.834570
# 261914   FR                    49.8           1.523390
# 261915   FR                    50.5           1.708170
# 261916   FR                    43.8           4.022790
# 261917   FR                    47.5           3.857730
# 261918   FR                    47.5           3.857730
# 261919   FR                    48.7          -2.804580
# 261920   FR                    46.7           4.366670
# 261921   FR                    43.9          -0.500476
# 261922   FR                    48.7           4.668470
# 261923   FR                    46.0           4.109920
# 261924   FR                    46.0           4.109920
# 261925   FR                    44.9           4.413940
# 262002   FR                    48.9           2.333330
# 262003   FR                    46.0           2.000000
# 262017   FR                    46.0           2.000000
# 262018   FR                    46.0           2.000000
# ...      ..                     ...                ...
# 3056963  FR                    46.0           4.109920
# 3056964  FR                    46.0           4.109920
# 3056965  FR                    46.0           4.109920
# 3056966  FR                    46.0           4.109920
# 3056978  FR                    46.0           4.109920
# 3056981  FR                    48.6           7.787350
# 3057019  FR                    48.6           7.787350
# 3057024  FR                    48.6           7.787350
# 3057036  FR                    48.9           2.333330
# 3057049  FR                    46.0           2.000000
# 3057050  FR                    46.0           2.000000
# 3057061  FR                    48.9           2.333330
# 3057065  FR                    46.0           2.000000
# 3057070  FR                    48.9           2.333330
# 3057078  FR                    46.0           2.000000
# 3057085  FR                    46.0           2.000000
# 3057097  FR                    48.9           2.333330
# 3057098  FR                    46.0           2.000000
# 3057102  FR                    48.9           2.333330
# 3057105  FR                    46.0           2.000000
# 3057119  FR                    48.9           2.333330
# 3057126  FR                    48.9           2.333330
# 3057132  FR                    46.0           2.000000
# 3057133  FR                    46.0           2.000000
# 3057139  FR                    48.9           2.333330
# 3057140  FR                    48.9           2.333330
# 3057151  FR                    48.9           2.333330
# 3057153  FR                    46.0           2.000000
# 3057157  FR                    46.0           2.000000
# 3057158  FR                    46.0           2.000000
#
#                          DOMAINNAME              LocationRegion  Event
# 97835    www.businessinsider.com     (46.0, 2.0)                 0
# 98391    humanitariannews.org        (48.9, 2.33333)             0
# 98405    www.livemint.com            (48.9, 2.33333)             0
# 98406    www.livemint.com            (48.9, 2.33333)             0
# 223627   www.upr.org                 (46.0, 2.0)                 0
# 261905   www.politico.eu             (48.9, 2.33333)             0
# 261906   www.ghananewsagency.org     (48.9, 2.33333)             0
# 261907   catholicherald.co.uk        (49.1, 0.226625)            0
# 261908   english.ahram.org.eg        (46.0, 2.0)                 0
# 261909   www.reuters.com             (48.9, 2.33333)             0
# 261910   newrepublic.com             (48.9, 2.55324)             0
# 261911   www.modernghana.com         (48.9, 2.33333)             0
# 261912   www.yahoo.com               (43.5, 5.44879)             0
# 261913   inpublic.globenewswire.com  (50.8, 1.83457)             0
# 261914   en.worldtempus.com          (49.8, 1.52339)             0
# 261915   www.thelocal.fr             (50.5, 1.70817)             0
# 261916   www.independent.ie          (43.8, 4.0227900000000005)  0
# 261917   www.express.co.uk           (47.5, 3.85773)             0
# 261918   www.express.co.uk           (47.5, 3.85773)             0
# 261919   www.wine-searcher.com       (48.7, -2.80458)            0
# 261920   mg.co.za                    (46.7, 4.36667)             0
# 261921   www.theguardian.com         (43.9, -0.500476)           0
# 261922   dailynewsegypt.com          (48.7, 4.66847)             0
# 261923   www.heraldsun.com.au        (46.0, 4.10992)             0
# 261924   mynorthwest.com             (46.0, 4.10992)             0
# 261925   www.modernghana.com         (44.9, 4.41394)             0
# 262002   www.marketwatch.com         (48.9, 2.33333)             0
# 262003   www.kten.com                (46.0, 2.0)                 0
# 262017   kokomoperspective.com       (46.0, 2.0)                 0
# 262018   rinf.com                    (46.0, 2.0)                 0
# ...           ...                            ...                ..
# 3056963  mobile.wnd.com              (46.0, 4.10992)             0
# 3056964  www.breakingnews.ie         (46.0, 4.10992)             0
# 3056965  www.stokesentinel.co.uk     (46.0, 4.10992)             0
# 3056966  www.wistv.com               (46.0, 4.10992)             0
# 3056978  mobile.wnd.com              (46.0, 4.10992)             0
# 3056981  news.yahoo.com              (48.6, 7.78735)             0
# 3057019  news.yahoo.com              (48.6, 7.78735)             0
# 3057024  sheikyermami.com            (48.6, 7.78735)             0
# 3057036  londonist.com               (48.9, 2.33333)             0
# 3057049  www.firstpost.com           (46.0, 2.0)                 0
# 3057050  www.greekherald.com         (46.0, 2.0)                 0
# 3057061  www.chronicle.co.zw         (48.9, 2.33333)             0
# 3057065  www.palestinemonitor.org    (46.0, 2.0)                 0
# 3057070  www.thelocal.it             (48.9, 2.33333)             0
# 3057078  nna-leb.gov.lb              (46.0, 2.0)                 0
# 3057085  www.radio.gov.pk            (46.0, 2.0)                 0
# 3057097  jamestown.org               (48.9, 2.33333)             0
# 3057098  euobserver.com              (46.0, 2.0)                 0
# 3057102  www.alternet.org            (48.9, 2.33333)             0
# 3057105  www.alaraby.co.uk           (46.0, 2.0)                 0
# 3057119  www.businessinsider.com     (48.9, 2.33333)             0
# 3057126  signalscv.com               (48.9, 2.33333)             0
# 3057132  time.com                    (46.0, 2.0)                 0
# 3057133  iranian.com                 (46.0, 2.0)                 0
# 3057139  www.theintelligencer.com    (48.9, 2.33333)             0
# 3057140  www.modernghana.com         (48.9, 2.33333)             0
# 3057151  www.modernghana.com         (48.9, 2.33333)             0
# 3057153  world.wng.org               (46.0, 2.0)                 0
# 3057157  www.sott.net                (46.0, 2.0)                 0
# 3057158  dailycaller.com             (46.0, 2.0)                 0
#
# [3204 rows x 15 columns]

# %%
france_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103885 entries, 0 to 3103884
# Data columns (total 15 columns):
# SQLDATE                  datetime64[ns]
# Actor1Name               object
# Actor2Name               object
# SOURCEURL                object
# MonthYear                int64
# EventRootCode            int64
# GoldsteinScale           float64
# NumMentions              int64
# AvgTone                  float64
# ActionGeo_CountryCode    object
# ActionGeo_Lat            float64
# ActionGeo_Long           float64
# DOMAINNAME               object
# LocationRegion           object
# Event                    int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(6)
# memory usage: 355.2+ MB

# %% [markdown]
# ### Delete non-numeric values

# %%
france_numeric = france_events[['SQLDATE', 'MonthYear', 'EventRootCode', 'GoldsteinScale', 'NumMentions', 'AvgTone','ActionGeo_Lat', 'ActionGeo_Long','Event']]

# %% [markdown]
# ### Sort values before train/test split

# %%
france_numeric = france_numeric.sort_values(by='SQLDATE')

# %%
split_date = pd.datetime(2016,12,20)

df_training = df.loc[df['Date'] <= split_date]
df_test = df.loc[df['Date'] > split_date]

# %% [markdown]
# ### Create a train/test split

# %%
split_date = pd.datetime(2018,12,31)
france_train = france_numeric.loc[france_numeric['SQLDATE'] <= split_date]
france_test = france_numeric.loc[france_numeric['SQLDATE'] > split_date]

# %% [markdown]
# ### Change SQLDATE to numeric

# %%
pd.to_timedelta(df.time).dt.total_seconds()

# %%
france_train['SQLDATE'] = france_train['SQLDATE'].astype(np.int64)
france_test['SQLDATE'] = france_test['SQLDATE'].astype(np.int64)

# %%
france_train.shape
# Out:
# (2712843, 9)

# %%
france_test.shape
# Out:
# (391042, 9)

# %% [markdown]
# ### Where the magic (or ML) happens: Use a Logistic Regression classifer to fit the data.

# %%
from sklearn.linear_model import LogisticRegression

classifer = LogisticRegression()

classifer.fit(france_train, france_train.Event)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Predict the testing data

# %%
y_pred = clf.predict(X_test)

# %%
y_predictions = classifer.predict(france_test)

# %% [markdown]
# ### Assess the results

# %%
from sklearn.metrics import classification_report

print(classification_report(france_test.Event, y_predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99    386522
#           1       0.00      0.00      0.00      4520
#
# avg / total       0.98      0.99      0.98    391042

# %% [markdown]
# ### And that's what you get when less than one percent of your events are from one category.
